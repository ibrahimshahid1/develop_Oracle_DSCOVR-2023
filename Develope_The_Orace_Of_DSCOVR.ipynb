# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrahimshahid1/develop_Oracle_DSCOVR-2023/blob/main/Develope_The_Orace_Of_DSCOVR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
data = pd.read_csv("dsc_fc_summed_spectra_2023_v01.csv")

# %%
data.head()
# Out:
#             date  vector1  vector2   vector3
# 0  1/1/2023 0:00 -2.70274  4.51236 -1.458060
# 1  1/1/2023 0:01 -2.82748  4.69308 -0.949090
# 2  1/1/2023 0:02 -1.87608  4.48063 -2.588770
# 3  1/1/2023 0:03 -2.71541  4.74902 -0.324706
# 4  1/1/2023 0:04 -2.93342  4.77895 -0.047584

# %%
data['vector1'] = pd.to_numeric(data['vector1'])
data['vector2'] = pd.to_numeric(data['vector2'])
data['vector3'] = pd.to_numeric(data['vector3'])

# %%
data
# Out:
#                   date  vector1  vector2   vector3
# 0        1/1/2023 0:00 -2.70274  4.51236 -1.458060
# 1        1/1/2023 0:01 -2.82748  4.69308 -0.949090
# 2        1/1/2023 0:02 -1.87608  4.48063 -2.588770
# 3        1/1/2023 0:03 -2.71541  4.74902 -0.324706
# 4        1/1/2023 0:04 -2.93342  4.77895 -0.047584
# ...                ...      ...      ...       ...
# 175675  5/2/2023 23:55  4.33665  2.80127  0.954633
# 175676  5/2/2023 23:56  4.66778  2.10582  1.260660
# 175677  5/2/2023 23:57  4.28322  3.02154  0.927773
# 175678  5/2/2023 23:58  4.31376  2.67727  1.723270
# 175679  5/2/2023 23:59  4.51542  2.30317  1.832570
#
# [175680 rows x 4 columns]

# %%
from datetime import datetime

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data['time'] = data['date'].dt.strftime("%H")
data['date'] = data['date'].dt.strftime("%d/%m/%Y")

# %%
data
# Out:
#               date  vector1  vector2   vector3 time
# 0       01/01/2023 -2.70274  4.51236 -1.458060   00
# 1       01/01/2023 -2.82748  4.69308 -0.949090   00
# 2       01/01/2023 -1.87608  4.48063 -2.588770   00
# 3       01/01/2023 -2.71541  4.74902 -0.324706   00
# 4       01/01/2023 -2.93342  4.77895 -0.047584   00
# ...            ...      ...      ...       ...  ...
# 175675  02/05/2023  4.33665  2.80127  0.954633   23
# 175676  02/05/2023  4.66778  2.10582  1.260660   23
# 175677  02/05/2023  4.28322  3.02154  0.927773   23
# 175678  02/05/2023  4.31376  2.67727  1.723270   23
# 175679  02/05/2023  4.51542  2.30317  1.832570   23
#
# [175680 rows x 5 columns]

# %%
df2 = data.groupby(['date','time']).sum()

# %%
df2
# Out:
#                     vector1     vector2     vector3
# date       time
# 01/01/2023 00   -125.105725  185.487482  -13.164504
#            01   -205.218188    6.429724  -14.559663
#            02   -208.117957   74.347098  -62.640237
#            03   -177.778204   80.835058  -16.813640
#            04   -177.835909  175.443413   82.051854
# ...                     ...         ...         ...
# 31/03/2023 19     89.313483   71.003141 -174.891550
#            20    -39.200102 -108.618560  -59.585449
#            21    115.141341 -125.847601  -68.098844
#            22     12.640961 -171.254898  -50.036859
#            23     94.361426 -217.205064   82.702789
#
# [2928 rows x 3 columns]

# %%
from matplotlib import pyplot as plt

# %%
x = np.arange(1, 2929, 1)

# %%
plt.gca().set_aspect(0.5)
plt.scatter(x, df2['vector1'], s=0.7)

# %%
data3 = pd.read_csv('kindex.txt', header=None, delimiter=r'\s+', names='year month date hour value1 value2 value3 Kp value4 value5'.split(' '))

# %%
data3
# Out:
#       year  month  date  hour  value1     value2      value3     Kp  value4  \
# 0     2023      1     1   0.0     1.5  33238.000  33238.0625  2.333       9
# 1     2023      1     1   3.0     4.5  33238.125  33238.1875  3.000      15
# 2     2023      1     1   6.0     7.5  33238.250  33238.3125  2.000       7
# 3     2023      1     1   9.0    10.5  33238.375  33238.4375  2.667      12
# 4     2023      1     1  12.0    13.5  33238.500  33238.5625  1.667       6
# ...    ...    ...   ...   ...     ...        ...         ...    ...     ...
# 2219  2023     10     5   9.0    10.5  33515.375  33515.4375  3.000      15
# 2220  2023     10     5  12.0    13.5  33515.500  33515.5625  1.667       6
# 2221  2023     10     5  15.0    16.5  33515.625  33515.6875  0.667       3
# 2222  2023     10     5  18.0    19.5  33515.750  33515.8125  0.667       3
# 2223  2023     10     5  21.0    22.5  33515.875  33515.9375  2.333       9
#
#       value5
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 2219       0
# 2220       0
# 2221       0
# 2222       0
# 2223       0
#
# [2224 rows x 10 columns]

# %%
data.set_index('date', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c2a3e87596fc> in <cell line: 1>()
# ----> 1 data.set_index('date', inplace=True)
#
# NameError: name 'data' is not defined
